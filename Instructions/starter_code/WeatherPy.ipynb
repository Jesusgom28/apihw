# %%
import sys
sys.executable
#while some plots don't match the answers they seems to look correct
# Out:
# 'C:\\Anaconda3\\envs\\PythonData\\python.exe'

# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key

api_key = "d5b774ebf0102f943e047d9ad75e3808"
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
len(df2['City'])
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "timizart"

query_url = url + "appid=" + api_key + "&q=" + city
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=timizart'

# %%
weather_response = requests.get(query_url)
weather_json = weather_response.json()
weather_json
# Out:
# {'coord': {'lon': 4.25, 'lat': 36.8},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 282.765,
#   'pressure': 1026.15,
#   'humidity': 75,
#   'temp_min': 282.765,
#   'temp_max': 282.765,
#   'sea_level': 1026.15,
#   'grnd_level': 961.17},
#  'wind': {'speed': 0.82, 'deg': 339.503},
#  'clouds': {'all': 0},
#  'dt': 1550947936,
#  'sys': {'message': 0.0036,
#   'country': 'DZ',
#   'sunrise': 1550902873,
#   'sunset': 1550943110},
#  'id': 2476396,
#  'name': 'Timizart',
#  'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df2 = pd.DataFrame({"City":cities})
df2
df2["Temp"] = np.nan
df2
df2["Humidity"] = np.nan
df2
df2["Cloudiness"] = np.nan
df2["Wind Speed"] = np.nan
df2
# Out:
#                City  Temp  Humidity  Cloudiness  Wind Speed
# 0      saint george   NaN       NaN         NaN         NaN
# 1            atuona   NaN       NaN         NaN         NaN
# 2            bethel   NaN       NaN         NaN         NaN
# 3             kapaa   NaN       NaN         NaN         NaN
# 4        chokurdakh   NaN       NaN         NaN         NaN
# 5           kahului   NaN       NaN         NaN         NaN
# 6              sola   NaN       NaN         NaN         NaN
# 7          katsuura   NaN       NaN         NaN         NaN
# 8           rikitea   NaN       NaN         NaN         NaN
# 9        talcahuano   NaN       NaN         NaN         NaN
# 10         thompson   NaN       NaN         NaN         NaN
# 11     punta arenas   NaN       NaN         NaN         NaN
# 12        rosenberg   NaN       NaN         NaN         NaN
# 13         barcelos   NaN       NaN         NaN         NaN
# 14          mataura   NaN       NaN         NaN         NaN
# 15     longyearbyen   NaN       NaN         NaN         NaN
# 16        busselton   NaN       NaN         NaN         NaN
# 17         bobonong   NaN       NaN         NaN         NaN
# 18        mahaicony   NaN       NaN         NaN         NaN
# 19   kulhudhuffushi   NaN       NaN         NaN         NaN
# 20           faanui   NaN       NaN         NaN         NaN
# 21      mys shmidta   NaN       NaN         NaN         NaN
# 22          ushuaia   NaN       NaN         NaN         NaN
# 23     fianarantsoa   NaN       NaN         NaN         NaN
# 24     khorramshahr   NaN       NaN         NaN         NaN
# 25           karwar   NaN       NaN         NaN         NaN
# 26            airai   NaN       NaN         NaN         NaN
# 27         klaksvik   NaN       NaN         NaN         NaN
# 28            tiksi   NaN       NaN         NaN         NaN
# 29          angoche   NaN       NaN         NaN         NaN
# ..              ...   ...       ...         ...         ...
# 585           rohru   NaN       NaN         NaN         NaN
# 586    isla mujeres   NaN       NaN         NaN         NaN
# 587          usinsk   NaN       NaN         NaN         NaN
# 588          conner   NaN       NaN         NaN         NaN
# 589        balakhta   NaN       NaN         NaN         NaN
# 590            buin   NaN       NaN         NaN         NaN
# 591        bucerias   NaN       NaN         NaN         NaN
# 592           jiazi   NaN       NaN         NaN         NaN
# 593         chotila   NaN       NaN         NaN         NaN
# 594            nome   NaN       NaN         NaN         NaN
# 595       abbeville   NaN       NaN         NaN         NaN
# 596           gamba   NaN       NaN         NaN         NaN
# 597        bilibino   NaN       NaN         NaN         NaN
# 598          kuytun   NaN       NaN         NaN         NaN
# 599           ambon   NaN       NaN         NaN         NaN
# 600        marsabit   NaN       NaN         NaN         NaN
# 601       loandjili   NaN       NaN         NaN         NaN
# 602      porto novo   NaN       NaN         NaN         NaN
# 603    gloversville   NaN       NaN         NaN         NaN
# 604        meulaboh   NaN       NaN         NaN         NaN
# 605         mashhad   NaN       NaN         NaN         NaN
# 606            nuuk   NaN       NaN         NaN         NaN
# 607       rawannawi   NaN       NaN         NaN         NaN
# 608          ilorin   NaN       NaN         NaN         NaN
# 609      carutapera   NaN       NaN         NaN         NaN
# 610   lago da pedra   NaN       NaN         NaN         NaN
# 611           hobyo   NaN       NaN         NaN         NaN
# 612         mokrous   NaN       NaN         NaN         NaN
# 613     deputatskiy   NaN       NaN         NaN         NaN
# 614         leiyang   NaN       NaN         NaN         NaN
#
# [615 rows x 5 columns]

# %%
for index, row in df2[0:100].iterrows():
    try:
        row = row.copy()
        city= row['City']
        print(city)

        url = "http://api.openweathermap.org/data/2.5/weather?"

        query_url = url + "appid=" + api_key + "&q=" + city
        print(query_url)

        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        print(weather_json)

        
        df2.at[index,"Temp"]= weather_json["main"]["temp"]
        df2.at[index,"Humidity"]= weather_json["main"]["humidity"]
        df2.at[index,"Cloudiness"]= weather_json["clouds"]["all"]
        df2.at[index,"Wind Speed"]= weather_json["wind"]["speed"]
        df2.at[index,"lat"]= weather_json["coord"]["lat"]
        df2.at[index,"lon"]= weather_json["coord"]["lon"]
       #DD OTHER 2 COLUMNS SAME WAY



    except KeyError:
        print(f"Oops, {row.copy()} doesn't exist.")
# Out:
# saint george
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=saint george
# {'coord': {'lon': 22.34, 'lat': 39.45}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 276.22, 'pressure': 1028, 'humidity': 80, 'temp_min': 275.15, 'temp_max': 277.15}, 'visibility': 10000, 'wind': {'speed': 3.1, 'deg': 70}, 'clouds': {'all': 90}, 'dt': 1550947800, 'sys': {'type': 1, 'id': 6629, 'message': 0.0035, 'country': 'GR', 'sunrise': 1550898699, 'sunset': 1550938605}, 'id': 262462, 'name': 'Saint George', 'cod': 200}
# atuona
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=atuona
# {'coord': {'lon': -139.03, 'lat': -9.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 300.66, 'pressure': 1012.46, 'humidity': 100, 'temp_min': 300.66, 'temp_max': 300.66, 'sea_level': 1012.46, 'grnd_level': 1012.42}, 'wind': {'speed': 7.31, 'deg': 91.0003}, 'clouds': {'all': 0}, 'dt': 1550950840, 'sys': {'message': 0.0038, 'country': 'PF', 'sunrise': 1550935159, 'sunset': 1550979551}, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# bethel
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=bethel
# {'coord': {'lon': -161.76, 'lat': 60.79}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 271.63, 'pressure': 1018, 'humidity': 81, 'temp_min': 270.15, 'temp_max': 273.15}, 'visibility': 16093, 'wind': {'speed': 5.1, 'deg': 100}, 'clouds': {'all': 1}, 'dt': 1550948160, 'sys': {'type': 1, 'id': 7640, 'message': 0.0044, 'country': 'US', 'sunrise': 1550944934, 'sunset': 1550980763}, 'id': 5880568, 'name': 'Bethel', 'cod': 200}
# kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=kapaa
# {'coord': {'lon': -159.32, 'lat': 22.08}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 296.15, 'pressure': 1017, 'humidity': 69, 'temp_min': 296.15, 'temp_max': 296.15}, 'visibility': 16093, 'wind': {'speed': 2.1, 'deg': 290}, 'clouds': {'all': 1}, 'dt': 1550948160, 'sys': {'type': 1, 'id': 7873, 'message': 0.0038, 'country': 'US', 'sunrise': 1550941341, 'sunset': 1550983134}, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=chokurdakh
# {'coord': {'lon': 147.9, 'lat': 70.62}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 238.36, 'pressure': 1014.98, 'humidity': 0, 'temp_min': 238.36, 'temp_max': 238.36, 'sea_level': 1014.98, 'grnd_level': 1012.58}, 'wind': {'speed': 2.41, 'deg': 203}, 'clouds': {'all': 12}, 'dt': 1550950841, 'sys': {'message': 0.0034, 'country': 'RU', 'sunrise': 1550873227, 'sunset': 1550903881}, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# kahului
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=kahului
# {'coord': {'lon': -156.47, 'lat': 20.89}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 295.49, 'pressure': 1017, 'humidity': 83, 'temp_min': 294.15, 'temp_max': 296.15}, 'visibility': 6437, 'wind': {'speed': 2.6, 'deg': 50}, 'rain': {'1h': 2.29}, 'clouds': {'all': 75}, 'dt': 1550949480, 'sys': {'type': 1, 'id': 7879, 'message': 0.0043, 'country': 'US', 'sunrise': 1550940604, 'sunset': 1550982501}, 'id': 5847411, 'name': 'Kahului', 'cod': 200}
# sola
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=sola
# {'coord': {'lon': 5.65, 'lat': 58.89}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 280.59, 'pressure': 1032, 'humidity': 81, 'temp_min': 280.15, 'temp_max': 281.15}, 'visibility': 8000, 'wind': {'speed': 6.7, 'deg': 160}, 'clouds': {'all': 40}, 'dt': 1550949600, 'sys': {'type': 1, 'id': 1680, 'message': 0.0045, 'country': 'NO', 'sunrise': 1550904545, 'sunset': 1550940799}, 'id': 3137942, 'name': 'Sola', 'cod': 200}
# katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=katsuura
# {'coord': {'lon': 134.5, 'lat': 33.93}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 276.15, 'pressure': 1023, 'humidity': 69, 'temp_min': 276.15, 'temp_max': 276.15}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 300}, 'clouds': {'all': 40}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8027, 'message': 0.0034, 'country': 'JP', 'sunrise': 1550871468, 'sunset': 1550911998}, 'id': 1865309, 'name': 'Katsuura', 'cod': 200}
# rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=rikitea
# {'coord': {'lon': -134.97, 'lat': -23.12}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 300.085, 'pressure': 1014.3, 'humidity': 99, 'temp_min': 300.085, 'temp_max': 300.085, 'sea_level': 1014.3, 'grnd_level': 1014.34}, 'wind': {'speed': 4.11, 'deg': 240}, 'clouds': {'all': 68}, 'dt': 1550950842, 'sys': {'message': 0.0033, 'country': 'PF', 'sunrise': 1550933584, 'sunset': 1550979165}, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# talcahuano
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=talcahuano
# {'coord': {'lon': -73.12, 'lat': -36.72}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 294.15, 'pressure': 1014, 'humidity': 56, 'temp_min': 294.15, 'temp_max': 294.15}, 'visibility': 10000, 'wind': {'speed': 9.8, 'deg': 230}, 'clouds': {'all': 0}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8499, 'message': 0.0037, 'country': 'CL', 'sunrise': 1550917959, 'sunset': 1550965089}, 'id': 3870282, 'name': 'Talcahuano', 'cod': 200}
# thompson
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=thompson
# {'coord': {'lon': -97.86, 'lat': 55.74}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 260.15, 'pressure': 1016, 'humidity': 65, 'temp_min': 260.15, 'temp_max': 260.15}, 'visibility': 24140, 'wind': {'speed': 4.1, 'deg': 340}, 'clouds': {'all': 75}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 935, 'message': 0.0034, 'country': 'CA', 'sunrise': 1550928927, 'sunset': 1550966091}, 'id': 6165406, 'name': 'Thompson', 'cod': 200}
# punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=punta arenas
# {'coord': {'lon': -70.91, 'lat': -53.16}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 282.15, 'pressure': 1008, 'humidity': 49, 'temp_min': 282.15, 'temp_max': 282.15}, 'visibility': 10000, 'wind': {'speed': 9.8, 'deg': 150}, 'clouds': {'all': 0}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8487, 'message': 0.0036, 'country': 'CL', 'sunrise': 1550915948, 'sunset': 1550966003}, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# rosenberg
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=rosenberg
# {'coord': {'lon': -95.81, 'lat': 29.56}, 'weather': [{'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 295.23, 'pressure': 1014, 'humidity': 37, 'temp_min': 294.15, 'temp_max': 296.15}, 'visibility': 16093, 'wind': {'speed': 5.1, 'deg': 320, 'gust': 8.7}, 'clouds': {'all': 1}, 'dt': 1550949300, 'sys': {'type': 1, 'id': 6039, 'message': 0.0042, 'country': 'US', 'sunrise': 1550926465, 'sunset': 1550967534}, 'id': 4723914, 'name': 'Rosenberg', 'cod': 200}
# barcelos
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=barcelos
# {'coord': {'lon': -8.62, 'lat': 41.53}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 287.15, 'pressure': 1029, 'humidity': 67, 'temp_min': 287.15, 'temp_max': 287.15}, 'visibility': 10000, 'wind': {'speed': 1.5, 'deg': 40}, 'clouds': {'all': 0}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 6900, 'message': 0.0037, 'country': 'PT', 'sunrise': 1550906261, 'sunset': 1550945904}, 'id': 2742416, 'name': 'Barcelos', 'cod': 200}
# mataura
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=mataura
# {'coord': {'lon': 168.86, 'lat': -46.19}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 282.835, 'pressure': 1014.62, 'humidity': 89, 'temp_min': 282.835, 'temp_max': 282.835, 'sea_level': 1014.62, 'grnd_level': 999.54}, 'wind': {'speed': 2.96, 'deg': 178.5}, 'rain': {'3h': 0.155}, 'clouds': {'all': 92}, 'dt': 1550950844, 'sys': {'message': 0.0043, 'country': 'NZ', 'sunrise': 1550859086, 'sunset': 1550907805}, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=longyearbyen
# {'coord': {'lon': 15.63, 'lat': 78.22}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 267.15, 'pressure': 997, 'humidity': 73, 'temp_min': 267.15, 'temp_max': 267.15}, 'visibility': 10000, 'wind': {'speed': 6.7, 'deg': 220}, 'clouds': {'all': 75}, 'dt': 1550947800, 'sys': {'type': 1, 'id': 1663, 'message': 0.0041, 'country': 'NO', 'sunrise': 1550910056, 'sunset': 1550930586}, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# busselton
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=busselton
# {'coord': {'lon': 115.35, 'lat': -33.64}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 290.71, 'pressure': 1018.74, 'humidity': 100, 'temp_min': 290.71, 'temp_max': 290.71, 'sea_level': 1018.74, 'grnd_level': 1017.7}, 'wind': {'speed': 4.61, 'deg': 160.5}, 'clouds': {'all': 0}, 'dt': 1550950844, 'sys': {'message': 0.0037, 'country': 'AU', 'sunrise': 1550872896, 'sunset': 1550919699}, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# bobonong
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=bobonong
# {'cod': '404', 'message': 'city not found'}
# Oops, City          bobonong
# Temp               NaN
# Humidity           NaN
# Cloudiness         NaN
# Wind Speed         NaN
# lat                NaN
# lon                NaN
# Name: 17, dtype: object doesn't exist.
# mahaicony
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=mahaicony
# {'cod': '404', 'message': 'city not found'}
# Oops, City          mahaicony
# Temp                NaN
# Humidity            NaN
# Cloudiness          NaN
# Wind Speed          NaN
# lat                 NaN
# lon                 NaN
# Name: 18, dtype: object doesn't exist.
# kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=kulhudhuffushi
# {'coord': {'lon': 73.07, 'lat': 6.62}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 301.035, 'pressure': 1009.7, 'humidity': 99, 'temp_min': 301.035, 'temp_max': 301.035, 'sea_level': 1009.7, 'grnd_level': 1009.7}, 'wind': {'speed': 3.86, 'deg': 46.5003}, 'clouds': {'all': 0}, 'dt': 1550950845, 'sys': {'message': 0.0028, 'country': 'MV', 'sunrise': 1550884931, 'sunset': 1550927995}, 'id': 1337613, 'name': 'Kulhudhuffushi', 'cod': 200}
# faanui
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=faanui
# {'coord': {'lon': -151.75, 'lat': -16.48}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 301.71, 'pressure': 1011.42, 'humidity': 98, 'temp_min': 301.71, 'temp_max': 301.71, 'sea_level': 1011.42, 'grnd_level': 1011.3}, 'wind': {'speed': 6.81, 'deg': 1.50031}, 'clouds': {'all': 0}, 'dt': 1550950845, 'sys': {'message': 0.0071, 'country': 'PF', 'sunrise': 1550937924, 'sunset': 1550982886}, 'id': 4034551, 'name': 'Faanui', 'cod': 200}
# mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=mys shmidta
# {'cod': '404', 'message': 'city not found'}
# Oops, City          mys shmidta
# Temp                  NaN
# Humidity              NaN
# Cloudiness            NaN
# Wind Speed            NaN
# lat                   NaN
# lon                   NaN
# Name: 21, dtype: object doesn't exist.
# ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=ushuaia
# {'coord': {'lon': -68.31, 'lat': -54.81}, 'weather': [{'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 280.15, 'pressure': 1008, 'humidity': 56, 'temp_min': 280.15, 'temp_max': 280.15}, 'visibility': 10000, 'wind': {'speed': 7.7, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8303, 'message': 0.0051, 'country': 'AR', 'sunrise': 1550915109, 'sunset': 1550965589}, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# fianarantsoa
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=fianarantsoa
# {'coord': {'lon': 47.09, 'lat': -21.45}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 291.135, 'pressure': 1010.62, 'humidity': 95, 'temp_min': 291.135, 'temp_max': 291.135, 'sea_level': 1010.62, 'grnd_level': 885.78}, 'wind': {'speed': 1.06, 'deg': 94.0003}, 'clouds': {'all': 56}, 'dt': 1550950846, 'sys': {'message': 0.0031, 'country': 'MG', 'sunrise': 1550889957, 'sunset': 1550935414}, 'id': 1064890, 'name': 'Fianarantsoa', 'cod': 200}
# khorramshahr
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=khorramshahr
# {'coord': {'lon': 48.18, 'lat': 30.43}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 289.71, 'pressure': 1016, 'humidity': 82, 'temp_min': 289.15, 'temp_max': 290.15}, 'visibility': 8000, 'wind': {'speed': 1, 'deg': 90}, 'clouds': {'all': 0}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 7439, 'message': 0.0035, 'country': 'IR', 'sunrise': 1550891977, 'sunset': 1550932915}, 'id': 127319, 'name': 'Khorramshahr', 'cod': 200}
# karwar
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=karwar
# {'coord': {'lon': 74.13, 'lat': 14.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 295.96, 'pressure': 1008.86, 'humidity': 50, 'temp_min': 295.96, 'temp_max': 295.96, 'sea_level': 1008.86, 'grnd_level': 970.1}, 'wind': {'speed': 0.06, 'deg': 48.5003}, 'clouds': {'all': 0}, 'dt': 1550950847, 'sys': {'message': 0.0033, 'country': 'IN', 'sunrise': 1550885019, 'sunset': 1550927405}, 'id': 1267635, 'name': 'Karwar', 'cod': 200}
# airai
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=airai
# {'coord': {'lon': 125.41, 'lat': -8.93}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 292.01, 'pressure': 1008.86, 'humidity': 86, 'temp_min': 292.01, 'temp_max': 292.01, 'sea_level': 1008.86, 'grnd_level': 933.3}, 'wind': {'speed': 0.61, 'deg': 34.0003}, 'clouds': {'all': 0}, 'dt': 1550950847, 'sys': {'message': 0.0039, 'country': 'TL', 'sunrise': 1550871726, 'sunset': 1550916067}, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=klaksvik
# {'coord': {'lon': -6.59, 'lat': 62.23}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 280.15, 'pressure': 1011, 'humidity': 81, 'temp_min': 280.15, 'temp_max': 280.15}, 'wind': {'speed': 9.8, 'deg': 260, 'gust': 18.5}, 'rain': {'3h': 0.455}, 'clouds': {'all': 0}, 'dt': 1550949600, 'sys': {'type': 1, 'id': 1596, 'message': 0.0036, 'country': 'FO', 'sunrise': 1550908017, 'sunset': 1550943211}, 'id': 2618795, 'name': 'Klaksvik', 'cod': 200}
# tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=tiksi
# {'coord': {'lon': 128.87, 'lat': 71.64}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 244.885, 'pressure': 1009.18, 'humidity': 27, 'temp_min': 244.885, 'temp_max': 244.885, 'sea_level': 1009.18, 'grnd_level': 989.94}, 'wind': {'speed': 4.06, 'deg': 225.5}, 'clouds': {'all': 32}, 'dt': 1550950848, 'sys': {'message': 0.0038, 'country': 'RU', 'sunrise': 1550878192, 'sunset': 1550908055}, 'id': 2015306, 'name': 'Tiksi', 'cod': 200}
# angoche
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=angoche
# {'coord': {'lon': 39.91, 'lat': -16.23}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 300.585, 'pressure': 1010.7, 'humidity': 100, 'temp_min': 300.585, 'temp_max': 300.585, 'sea_level': 1010.7, 'grnd_level': 1010.58}, 'wind': {'speed': 4.11, 'deg': 206}, 'clouds': {'all': 76}, 'dt': 1550950848, 'sys': {'message': 0.0032, 'country': 'MZ', 'sunrise': 1550891927, 'sunset': 1550936895}, 'id': 1052944, 'name': 'Angoche', 'cod': 200}
# puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=puerto ayora
# {'coord': {'lon': -90.35, 'lat': -0.74}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 303.15, 'pressure': 1011, 'humidity': 66, 'temp_min': 303.15, 'temp_max': 303.15}, 'visibility': 10000, 'wind': {'speed': 3.1, 'deg': 40}, 'clouds': {'all': 75}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8521, 'message': 0.0031, 'country': 'EC', 'sunrise': 1550923847, 'sunset': 1550967507}, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=nanortalik
# {'coord': {'lon': -45.24, 'lat': 60.14}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 267.785, 'pressure': 994.3, 'humidity': 100, 'temp_min': 267.785, 'temp_max': 267.785, 'sea_level': 994.3, 'grnd_level': 982.1}, 'wind': {'speed': 3.11, 'deg': 341}, 'clouds': {'all': 20}, 'dt': 1550950848, 'sys': {'message': 0.0036, 'country': 'GL', 'sunrise': 1550916923, 'sunset': 1550952849}, 'id': 3421765, 'name': 'Nanortalik', 'cod': 200}
# yeniseysk
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=yeniseysk
# {'coord': {'lon': 92.17, 'lat': 58.45}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 268.335, 'pressure': 1023.74, 'humidity': 83, 'temp_min': 268.335, 'temp_max': 268.335, 'sea_level': 1023.74, 'grnd_level': 1002.34}, 'wind': {'speed': 2.76, 'deg': 236.5}, 'clouds': {'all': 92}, 'dt': 1550950849, 'sys': {'message': 0.0038, 'country': 'RU', 'sunrise': 1550883756, 'sunset': 1550920062}, 'id': 1485997, 'name': 'Yeniseysk', 'cod': 200}
# wukari
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=wukari
# {'coord': {'lon': 9.78, 'lat': 7.87}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 301.785, 'pressure': 1009.02, 'humidity': 58, 'temp_min': 301.785, 'temp_max': 301.785, 'sea_level': 1009.02, 'grnd_level': 992.1}, 'wind': {'speed': 6.01, 'deg': 200}, 'clouds': {'all': 56}, 'dt': 1550950849, 'sys': {'message': 0.0031, 'country': 'NG', 'sunrise': 1550900169, 'sunset': 1550943135}, 'id': 2318921, 'name': 'Wukari', 'cod': 200}
# avarua
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=avarua
# {'coord': {'lon': -159.78, 'lat': -21.21}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 301.15, 'pressure': 1007, 'humidity': 69, 'temp_min': 301.15, 'temp_max': 301.15}, 'visibility': 10000, 'wind': {'speed': 4.1, 'deg': 250}, 'clouds': {'all': 36}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 7271, 'message': 0.0042, 'country': 'CK', 'sunrise': 1550939633, 'sunset': 1550985025}, 'id': 4035715, 'name': 'Avarua', 'cod': 200}
# ancud
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=ancud
# {'coord': {'lon': -73.83, 'lat': -41.87}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 288.15, 'pressure': 1018, 'humidity': 58, 'temp_min': 288.15, 'temp_max': 288.15}, 'visibility': 10000, 'wind': {'speed': 2.6}, 'clouds': {'all': 75}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8512, 'message': 0.0031, 'country': 'CL', 'sunrise': 1550917757, 'sunset': 1550965623}, 'id': 3899695, 'name': 'Ancud', 'cod': 200}
# nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=nouadhibou
# {'coord': {'lon': -17.03, 'lat': 20.93}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 298.15, 'pressure': 1016, 'humidity': 27, 'temp_min': 298.15, 'temp_max': 298.15}, 'visibility': 7000, 'wind': {'speed': 3.6, 'deg': 320}, 'clouds': {'all': 0}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 2444, 'message': 0.0051, 'country': 'MR', 'sunrise': 1550907157, 'sunset': 1550949024}, 'id': 2377457, 'name': 'Nouadhibou', 'cod': 200}
# hokitika
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=hokitika
# {'coord': {'lon': 170.96, 'lat': -42.72}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 287.76, 'pressure': 1003.46, 'humidity': 94, 'temp_min': 287.76, 'temp_max': 287.76, 'sea_level': 1003.46, 'grnd_level': 992.58}, 'wind': {'speed': 6.86, 'deg': 137.5}, 'clouds': {'all': 68}, 'dt': 1550950850, 'sys': {'message': 0.0028, 'country': 'NZ', 'sunrise': 1550858887, 'sunset': 1550907003}, 'id': 2206894, 'name': 'Hokitika', 'cod': 200}
# borshchiv
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=borshchiv
# {'coord': {'lon': 26.04, 'lat': 48.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 269.15, 'pressure': 1039, 'humidity': 58, 'temp_min': 269.15, 'temp_max': 269.15}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8908, 'message': 0.0035, 'country': 'UA', 'sunrise': 1550898520, 'sunset': 1550937020}, 'id': 711587, 'name': 'Borshchiv', 'cod': 200}
# barrow
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=barrow
# {'coord': {'lon': -60.23, 'lat': -38.31}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 295.085, 'pressure': 1002.26, 'humidity': 72, 'temp_min': 295.085, 'temp_max': 295.085, 'sea_level': 1002.26, 'grnd_level': 990.66}, 'wind': {'speed': 6.11, 'deg': 255}, 'rain': {'3h': 0.46}, 'clouds': {'all': 12}, 'dt': 1550950851, 'sys': {'message': 0.0042, 'country': 'AR', 'sunrise': 1550914754, 'sunset': 1550962104}, 'id': 3833859, 'name': 'Barrow', 'cod': 200}
# hobart
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=hobart
# {'coord': {'lon': 147.33, 'lat': -42.88}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 282.15, 'pressure': 1030, 'humidity': 87, 'temp_min': 282.15, 'temp_max': 282.15}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 320}, 'clouds': {'all': 0}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 9545, 'message': 0.0042, 'country': 'AU', 'sunrise': 1550864550, 'sunset': 1550912681}, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=port alfred
# {'coord': {'lon': 26.89, 'lat': -33.59}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 294.51, 'pressure': 1012.74, 'humidity': 95, 'temp_min': 294.51, 'temp_max': 294.51, 'sea_level': 1012.74, 'grnd_level': 1004.1}, 'wind': {'speed': 3.61, 'deg': 256}, 'rain': {'3h': 1.425}, 'clouds': {'all': 92}, 'dt': 1550950851, 'sys': {'message': 0.0036, 'country': 'ZA', 'sunrise': 1550894143, 'sunset': 1550940909}, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# maraba
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=maraba
# {'coord': {'lon': -49.1, 'lat': -5.35}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 305.15, 'pressure': 1008, 'humidity': 62, 'temp_min': 305.15, 'temp_max': 305.15}, 'visibility': 10000, 'wind': {'speed': 3.1, 'deg': 340}, 'clouds': {'all': 40}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8403, 'message': 0.0031, 'country': 'BR', 'sunrise': 1550913760, 'sunset': 1550957792}, 'id': 3395503, 'name': 'Maraba', 'cod': 200}
# turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=turukhansk
# {'coord': {'lon': 87.96, 'lat': 65.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 244.61, 'pressure': 1015.18, 'humidity': 27, 'temp_min': 244.61, 'temp_max': 244.61, 'sea_level': 1015.18, 'grnd_level': 999.22}, 'wind': {'speed': 1.36, 'deg': 61.0003}, 'clouds': {'all': 0}, 'dt': 1550950852, 'sys': {'message': 0.0036, 'country': 'RU', 'sunrise': 1550886117, 'sunset': 1550919741}, 'id': 1488903, 'name': 'Turukhansk', 'cod': 200}
# ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=ostrovnoy
# {'coord': {'lon': 39.51, 'lat': 68.05}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 273.41, 'pressure': 1007.74, 'humidity': 93, 'temp_min': 273.41, 'temp_max': 273.41, 'sea_level': 1007.74, 'grnd_level': 981.94}, 'wind': {'speed': 7.61, 'deg': 296}, 'clouds': {'all': 88}, 'dt': 1550950852, 'sys': {'message': 0.0083, 'country': 'RU', 'sunrise': 1550898304, 'sunset': 1550930815}, 'id': 556268, 'name': 'Ostrovnoy', 'cod': 200}
# pringsewu
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=pringsewu
# {'coord': {'lon': 104.98, 'lat': -5.36}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 295.41, 'pressure': 1009.58, 'humidity': 95, 'temp_min': 295.41, 'temp_max': 295.41, 'sea_level': 1009.58, 'grnd_level': 984.66}, 'wind': {'speed': 1.31, 'deg': 355}, 'clouds': {'all': 80}, 'dt': 1550950852, 'sys': {'message': 0.0034, 'country': 'ID', 'sunrise': 1550876780, 'sunset': 1550920821}, 'id': 1630639, 'name': 'Pringsewu', 'cod': 200}
# coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=coihaique
# {'coord': {'lon': -72.07, 'lat': -45.58}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 286.15, 'pressure': 1013, 'humidity': 43, 'temp_min': 286.15, 'temp_max': 286.15}, 'visibility': 10000, 'wind': {'speed': 5.1, 'gust': 10.3}, 'clouds': {'all': 75}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8491, 'message': 0.0035, 'country': 'CL', 'sunrise': 1550917024, 'sunset': 1550965504}, 'id': 3894426, 'name': 'Coihaique', 'cod': 200}
# new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=new norfolk
# {'coord': {'lon': 147.06, 'lat': -42.78}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 282.15, 'pressure': 1030, 'humidity': 87, 'temp_min': 282.15, 'temp_max': 282.15}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 320}, 'clouds': {'all': 0}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 9545, 'message': 0.0034, 'country': 'AU', 'sunrise': 1550864624, 'sunset': 1550912738}, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# cape town
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=cape town
# {'coord': {'lon': 18.42, 'lat': -33.93}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 294.15, 'pressure': 1014, 'humidity': 94, 'temp_min': 294.15, 'temp_max': 294.15}, 'visibility': 10000, 'wind': {'speed': 7.2, 'deg': 200}, 'clouds': {'all': 20}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 1899, 'message': 0.0059, 'country': 'ZA', 'sunrise': 1550896155, 'sunset': 1550942961}, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=tuatapere
# {'coord': {'lon': 167.69, 'lat': -46.13}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 283.235, 'pressure': 1015.22, 'humidity': 100, 'temp_min': 283.235, 'temp_max': 283.235, 'sea_level': 1015.22, 'grnd_level': 990.1}, 'wind': {'speed': 5.61, 'deg': 167.5}, 'clouds': {'all': 92}, 'dt': 1550950853, 'sys': {'message': 0.0036, 'country': 'NZ', 'sunrise': 1550859373, 'sunset': 1550908080}, 'id': 2180815, 'name': 'Tuatapere', 'cod': 200}
# taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=taolanaro
# {'cod': '404', 'message': 'city not found'}
# Oops, City          taolanaro
# Temp                NaN
# Humidity            NaN
# Cloudiness          NaN
# Wind Speed          NaN
# lat                 NaN
# lon                 NaN
# Name: 50, dtype: object doesn't exist.
# ngukurr
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=ngukurr
# {'cod': '404', 'message': 'city not found'}
# Oops, City          ngukurr
# Temp              NaN
# Humidity          NaN
# Cloudiness        NaN
# Wind Speed        NaN
# lat               NaN
# lon               NaN
# Name: 51, dtype: object doesn't exist.
# vaini
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=vaini
# {'coord': {'lon': 74.49, 'lat': 15.34}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 292.11, 'pressure': 1009.5, 'humidity': 65, 'temp_min': 292.11, 'temp_max': 292.11, 'sea_level': 1009.5, 'grnd_level': 945.7}, 'wind': {'speed': 1.06, 'deg': 64.5003}, 'clouds': {'all': 0}, 'dt': 1550950854, 'sys': {'message': 0.003, 'country': 'IN', 'sunrise': 1550884956, 'sunset': 1550927296}, 'id': 1273574, 'name': 'Vaini', 'cod': 200}
# qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=qaanaaq
# {'coord': {'lon': -69.36, 'lat': 77.48}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 247.635, 'pressure': 1002.66, 'humidity': 100, 'temp_min': 247.635, 'temp_max': 247.635, 'sea_level': 1002.66, 'grnd_level': 968.18}, 'wind': {'speed': 2.86, 'deg': 26.0003}, 'clouds': {'all': 32}, 'dt': 1550950854, 'sys': {'message': 0.0129, 'country': 'GL', 'sunrise': 1550929437, 'sunset': 1550951990}, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# tshane
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=tshane
# {'coord': {'lon': 21.87, 'lat': -24.02}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 293.91, 'pressure': 1010.18, 'humidity': 73, 'temp_min': 293.91, 'temp_max': 293.91, 'sea_level': 1010.18, 'grnd_level': 886.1}, 'wind': {'speed': 0.66, 'deg': 335}, 'rain': {'3h': 1.48}, 'clouds': {'all': 100}, 'dt': 1550950855, 'sys': {'message': 0.0035, 'country': 'BW', 'sunrise': 1550895884, 'sunset': 1550941589}, 'id': 933726, 'name': 'Tshane', 'cod': 200}
# saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=saint-philippe
# {'coord': {'lon': -73.48, 'lat': 45.36}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 273.17, 'pressure': 1029, 'humidity': 54, 'temp_min': 272.15, 'temp_max': 274.15}, 'visibility': 14484, 'wind': {'speed': 3.6, 'deg': 130}, 'clouds': {'all': 1}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 820, 'message': 0.0037, 'country': 'CA', 'sunrise': 1550922089, 'sunset': 1550961211}, 'id': 6138908, 'name': 'Saint-Philippe', 'cod': 200}
# namibe
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=namibe
# {'coord': {'lon': 12.15, 'lat': -15.19}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 298.16, 'pressure': 1010.9, 'humidity': 100, 'temp_min': 298.16, 'temp_max': 298.16, 'sea_level': 1010.9, 'grnd_level': 1007.22}, 'wind': {'speed': 4.46, 'deg': 214.5}, 'clouds': {'all': 24}, 'dt': 1550950855, 'sys': {'message': 0.0044, 'country': 'AO', 'sunrise': 1550898638, 'sunset': 1550943509}, 'id': 3347019, 'name': 'Namibe', 'cod': 200}
# montepuez
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=montepuez
# {'coord': {'lon': 39, 'lat': -13.13}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 296.335, 'pressure': 1011.02, 'humidity': 89, 'temp_min': 296.335, 'temp_max': 296.335, 'sea_level': 1011.02, 'grnd_level': 956.18}, 'wind': {'speed': 3.41, 'deg': 2.50031}, 'rain': {'3h': 0.27}, 'clouds': {'all': 0}, 'dt': 1550950855, 'sys': {'message': 0.0026, 'country': 'MZ', 'sunrise': 1550892284, 'sunset': 1550936978}, 'id': 1037125, 'name': 'Montepuez', 'cod': 200}
# pangoa
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=pangoa
# {'coord': {'lon': -73, 'lat': -12.12}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 297.66, 'pressure': 1004.42, 'humidity': 85, 'temp_min': 297.66, 'temp_max': 297.66, 'sea_level': 1004.42, 'grnd_level': 882.18}, 'wind': {'speed': 1.16, 'deg': 0.000305176}, 'rain': {'3h': 1.77}, 'clouds': {'all': 36}, 'dt': 1550950856, 'sys': {'message': 0.0033, 'country': 'PE', 'sunrise': 1550919212, 'sunset': 1550963806}, 'id': 3933104, 'name': 'Pangoa', 'cod': 200}
# tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=tuktoyaktuk
# {'coord': {'lon': -133.03, 'lat': 69.44}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 248.15, 'pressure': 1027, 'humidity': 83, 'temp_min': 248.15, 'temp_max': 248.15}, 'visibility': 24140, 'wind': {'speed': 4.1, 'deg': 140}, 'clouds': {'all': 20}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 942, 'message': 0.0039, 'country': 'CA', 'sunrise': 1550940014, 'sunset': 1550971923}, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# chuy
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=chuy
# {'coord': {'lon': -53.46, 'lat': -33.69}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 295.61, 'pressure': 1002.74, 'humidity': 100, 'temp_min': 295.61, 'temp_max': 295.61, 'sea_level': 1002.74, 'grnd_level': 1001.3}, 'wind': {'speed': 1.96, 'deg': 70.5003}, 'rain': {'3h': 4.465}, 'clouds': {'all': 64}, 'dt': 1550950856, 'sys': {'message': 0.0033, 'country': 'UY', 'sunrise': 1550913432, 'sunset': 1550960184}, 'id': 3443061, 'name': 'Chuy', 'cod': 200}
# iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=iqaluit
# {'coord': {'lon': -68.52, 'lat': 63.75}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 249.15, 'pressure': 1012, 'humidity': 69, 'temp_min': 249.15, 'temp_max': 249.15}, 'visibility': 32186, 'wind': {'speed': 4.1, 'deg': 340}, 'clouds': {'all': 75}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 797, 'message': 0.0044, 'country': 'CA', 'sunrise': 1550923134, 'sunset': 1550957821}, 'id': 5983720, 'name': 'Iqaluit', 'cod': 200}
# castro
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=castro
# {'coord': {'lon': -73.76, 'lat': -42.48}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 288.15, 'pressure': 1018, 'humidity': 58, 'temp_min': 288.15, 'temp_max': 288.15}, 'visibility': 10000, 'wind': {'speed': 2.6}, 'clouds': {'all': 75}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8512, 'message': 0.0032, 'country': 'CL', 'sunrise': 1550917692, 'sunset': 1550965653}, 'id': 3896218, 'name': 'Castro', 'cod': 200}
# saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=saint-augustin
# {'coord': {'lon': -0.61, 'lat': 44.83}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 282.92, 'pressure': 1029, 'humidity': 71, 'temp_min': 281.15, 'temp_max': 285.15}, 'visibility': 10000, 'wind': {'speed': 1.5, 'deg': 290}, 'clouds': {'all': 0}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 6450, 'message': 0.0038, 'country': 'FR', 'sunrise': 1550904580, 'sunset': 1550943745}, 'id': 3031582, 'name': 'Saint-Augustin', 'cod': 200}
# taiyuan
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=taiyuan
# {'coord': {'lon': 112.56, 'lat': 37.86}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 271.15, 'pressure': 1022, 'humidity': 54, 'temp_min': 271.15, 'temp_max': 271.15}, 'visibility': 5000, 'wind': {'speed': 1, 'deg': 100}, 'clouds': {'all': 8}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 9616, 'message': 0.0038, 'country': 'CN', 'sunrise': 1550876965, 'sunset': 1550917035}, 'id': 1793511, 'name': 'Taiyuan', 'cod': 200}
# saint-joseph
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=saint-joseph
# {'coord': {'lon': 6.97, 'lat': 43.56}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 281.81, 'pressure': 1029, 'humidity': 81, 'temp_min': 281.15, 'temp_max': 283.15}, 'visibility': 10000, 'wind': {'speed': 1}, 'clouds': {'all': 0}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 6507, 'message': 0.0041, 'country': 'FR', 'sunrise': 1550902668, 'sunset': 1550942018}, 'id': 3037456, 'name': 'Saint-Joseph', 'cod': 200}
# te anau
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=te anau
# {'coord': {'lon': 167.72, 'lat': -45.41}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 278.71, 'pressure': 1014.22, 'humidity': 98, 'temp_min': 278.71, 'temp_max': 278.71, 'sea_level': 1014.22, 'grnd_level': 949.7}, 'wind': {'speed': 2.51, 'deg': 154}, 'rain': {'3h': 0.565}, 'clouds': {'all': 92}, 'dt': 1550950858, 'sys': {'message': 0.0038, 'country': 'NZ', 'sunrise': 1550859432, 'sunset': 1550908008}, 'id': 2181625, 'name': 'Te Anau', 'cod': 200}
# amderma
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=amderma
# {'cod': '404', 'message': 'city not found'}
# Oops, City          amderma
# Temp              NaN
# Humidity          NaN
# Cloudiness        NaN
# Wind Speed        NaN
# lat               NaN
# lon               NaN
# Name: 67, dtype: object doesn't exist.
# bluff
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=bluff
# {'coord': {'lon': 149.07, 'lat': -23.58}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 294.785, 'pressure': 1016.46, 'humidity': 77, 'temp_min': 294.785, 'temp_max': 294.785, 'sea_level': 1016.46, 'grnd_level': 993.94}, 'wind': {'speed': 1.66, 'deg': 131.5}, 'clouds': {'all': 32}, 'dt': 1550950859, 'sys': {'message': 0.0034, 'country': 'AU', 'sunrise': 1550865367, 'sunset': 1550911056}, 'id': 2175403, 'name': 'Bluff', 'cod': 200}
# sistranda
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=sistranda
# {'coord': {'lon': 8.83, 'lat': 63.73}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 280.15, 'pressure': 1021, 'humidity': 81, 'temp_min': 280.15, 'temp_max': 280.15}, 'visibility': 10000, 'wind': {'speed': 4.1, 'deg': 110}, 'clouds': {'all': 0}, 'dt': 1550949600, 'sys': {'type': 1, 'id': 1647, 'message': 0.0036, 'country': 'NO', 'sunrise': 1550904609, 'sunset': 1550939222}, 'id': 3139597, 'name': 'Sistranda', 'cod': 200}
# sorvag
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=sorvag
# {'cod': '404', 'message': 'city not found'}
# Oops, City          sorvag
# Temp             NaN
# Humidity         NaN
# Cloudiness       NaN
# Wind Speed       NaN
# lat              NaN
# lon              NaN
# Name: 70, dtype: object doesn't exist.
# esperance
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=esperance
# {'coord': {'lon': -61.45, 'lat': 10.24}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 303.15, 'pressure': 1014, 'humidity': 48, 'temp_min': 303.15, 'temp_max': 303.15}, 'visibility': 10000, 'wind': {'speed': 9.3, 'deg': 100}, 'clouds': {'all': 40}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8810, 'message': 0.0032, 'country': 'TT', 'sunrise': 1550917356, 'sunset': 1550960136}, 'id': 3573739, 'name': 'Esperance', 'cod': 200}
# san ignacio
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=san ignacio
# {'coord': {'lon': -72.03, 'lat': -36.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 301.15, 'pressure': 1012, 'humidity': 28, 'temp_min': 301.15, 'temp_max': 301.15}, 'visibility': 10000, 'wind': {'speed': 7.7, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8483, 'message': 0.0034, 'country': 'CL', 'sunrise': 1550917692, 'sunset': 1550964832}, 'id': 3872175, 'name': 'San Ignacio', 'cod': 200}
# altay
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=altay
# {'coord': {'lon': 88.13, 'lat': 47.83}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 249.885, 'pressure': 1037.5, 'humidity': 55, 'temp_min': 249.885, 'temp_max': 249.885, 'sea_level': 1037.5, 'grnd_level': 814.42}, 'wind': {'speed': 1.01, 'deg': 53.5003}, 'clouds': {'all': 0}, 'dt': 1550950860, 'sys': {'message': 0.0033, 'country': 'CN', 'sunrise': 1550883552, 'sunset': 1550922186}, 'id': 1529651, 'name': 'Altay', 'cod': 200}
# kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=kodiak
# {'coord': {'lon': -94.76, 'lat': 39.95}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}, {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 275.48, 'pressure': 1001, 'humidity': 100, 'temp_min': 275.15, 'temp_max': 276.15}, 'visibility': 1207, 'wind': {'speed': 3.6, 'deg': 50}, 'clouds': {'all': 90}, 'dt': 1550949300, 'sys': {'type': 1, 'id': 4022, 'message': 0.0033, 'country': 'US', 'sunrise': 1550926808, 'sunset': 1550966698}, 'id': 4407665, 'name': 'Kodiak', 'cod': 200}
# vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=vila velha
# {'coord': {'lon': -38.6, 'lat': -3.71}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 301.15, 'pressure': 1009, 'humidity': 78, 'temp_min': 301.15, 'temp_max': 301.15}, 'visibility': 10000, 'wind': {'speed': 3.1, 'deg': 60}, 'clouds': {'all': 75}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8363, 'message': 0.0036, 'country': 'BR', 'sunrise': 1550911307, 'sunset': 1550955207}, 'id': 6320062, 'name': 'Vila Velha', 'cod': 200}
# kirovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=kirovskiy
# {'coord': {'lon': 133.51, 'lat': 45.09}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 273.985, 'pressure': 1011.82, 'humidity': 49, 'temp_min': 273.985, 'temp_max': 273.985, 'sea_level': 1011.82, 'grnd_level': 984.18}, 'wind': {'speed': 3.76, 'deg': 229.5}, 'clouds': {'all': 76}, 'dt': 1550950861, 'sys': {'message': 0.0032, 'country': 'RU', 'sunrise': 1550872449, 'sunset': 1550911505}, 'id': 2022064, 'name': 'Kirovskiy', 'cod': 200}
# the valley
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=the valley
# {'coord': {'lon': -63.06, 'lat': 18.22}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 300.19, 'pressure': 1019, 'humidity': 61, 'temp_min': 299.15, 'temp_max': 301.15}, 'visibility': 10000, 'wind': {'speed': 5.7, 'deg': 80}, 'clouds': {'all': 40}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8788, 'message': 0.0038, 'country': 'AI', 'sunrise': 1550918079, 'sunset': 1550960192}, 'id': 3573374, 'name': 'The Valley', 'cod': 200}
# sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=sao filipe
# {'coord': {'lon': -24.5, 'lat': 14.9}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 297.01, 'pressure': 1015.1, 'humidity': 82, 'temp_min': 297.01, 'temp_max': 297.01, 'sea_level': 1015.1, 'grnd_level': 1003.46}, 'wind': {'speed': 7.01, 'deg': 56.5003}, 'clouds': {'all': 0}, 'dt': 1550950862, 'sys': {'message': 0.0034, 'country': 'CV', 'sunrise': 1550908686, 'sunset': 1550951076}, 'id': 3374210, 'name': 'Sao Filipe', 'cod': 200}
# maumee
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=maumee
# {'coord': {'lon': -83.65, 'lat': 41.56}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 276.71, 'pressure': 1015, 'humidity': 80, 'temp_min': 275.15, 'temp_max': 279.15}, 'visibility': 16093, 'wind': {'speed': 5.1, 'deg': 90, 'gust': 7.7}, 'clouds': {'all': 90}, 'dt': 1550949360, 'sys': {'type': 1, 'id': 3875, 'message': 0.0039, 'country': 'US', 'sunrise': 1550924252, 'sunset': 1550963925}, 'id': 5162137, 'name': 'Maumee', 'cod': 200}
# torbay
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=torbay
# {'coord': {'lon': -52.73, 'lat': 47.66}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 262.15, 'pressure': 1008, 'humidity': 47, 'temp_min': 262.15, 'temp_max': 262.15}, 'visibility': 24140, 'wind': {'speed': 11.3, 'deg': 300, 'gust': 14.4}, 'clouds': {'all': 20}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 998, 'message': 0.0047, 'country': 'CA', 'sunrise': 1550917301, 'sunset': 1550956043}, 'id': 6167817, 'name': 'Torbay', 'cod': 200}
# khonuu
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=khonuu
# {'cod': '404', 'message': 'city not found'}
# Oops, City          khonuu
# Temp             NaN
# Humidity         NaN
# Cloudiness       NaN
# Wind Speed       NaN
# lat              NaN
# lon              NaN
# Name: 81, dtype: object doesn't exist.
# provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=provideniya
# {'coord': {'lon': -173.23, 'lat': 64.42}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 273.46, 'pressure': 1000.18, 'humidity': 94, 'temp_min': 273.46, 'temp_max': 273.46, 'sea_level': 1000.18, 'grnd_level': 994.18}, 'wind': {'speed': 13.21, 'deg': 149.5}, 'clouds': {'all': 92}, 'dt': 1550950863, 'sys': {'message': 0.0036, 'country': 'RU', 'sunrise': 1550948340, 'sunset': 1550982873}, 'id': 4031574, 'name': 'Provideniya', 'cod': 200}
# san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=san cristobal
# {'coord': {'lon': -78.55, 'lat': -0.39}, 'weather': [{'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 294.09, 'pressure': 1023, 'humidity': 49, 'temp_min': 293.15, 'temp_max': 295.15}, 'visibility': 10000, 'wind': {'speed': 7.7, 'deg': 330}, 'clouds': {'all': 40}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8555, 'message': 0.0041, 'country': 'EC', 'sunrise': 1550921029, 'sunset': 1550964661}, 'id': 3652462, 'name': 'San Cristobal', 'cod': 200}
# necochea
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=necochea
# {'coord': {'lon': -58.74, 'lat': -38.55}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 295.585, 'pressure': 1001.42, 'humidity': 73, 'temp_min': 295.585, 'temp_max': 295.585, 'sea_level': 1001.42, 'grnd_level': 995.78}, 'wind': {'speed': 6.81, 'deg': 268}, 'clouds': {'all': 68}, 'dt': 1550950650, 'sys': {'message': 0.0032, 'country': 'AR', 'sunrise': 1550914379, 'sunset': 1550961764}, 'id': 3430443, 'name': 'Necochea', 'cod': 200}
# yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=yellowknife
# {'coord': {'lon': -114.38, 'lat': 62.45}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 246.15, 'pressure': 1037, 'humidity': 62, 'temp_min': 246.15, 'temp_max': 246.15}, 'visibility': 24140, 'wind': {'speed': 4.1, 'deg': 350}, 'clouds': {'all': 5}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 1007, 'message': 0.0038, 'country': 'CA', 'sunrise': 1550933869, 'sunset': 1550969093}, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=tasiilaq
# {'coord': {'lon': -37.64, 'lat': 65.61}, 'weather': [{'id': 615, 'main': 'Snow', 'description': 'light rain and snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 274.15, 'pressure': 985, 'humidity': 80, 'temp_min': 274.15, 'temp_max': 274.15}, 'visibility': 3000, 'wind': {'speed': 8.7, 'deg': 260}, 'clouds': {'all': 75}, 'dt': 1550947800, 'sys': {'type': 1, 'id': 81, 'message': 0.0036, 'country': 'GL', 'sunrise': 1550916139, 'sunset': 1550950000}, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=hermanus
# {'coord': {'lon': 19.24, 'lat': -34.42}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 289.785, 'pressure': 1014.22, 'humidity': 94, 'temp_min': 289.785, 'temp_max': 289.785, 'sea_level': 1014.22, 'grnd_level': 975.46}, 'wind': {'speed': 1.26, 'deg': 156}, 'clouds': {'all': 20}, 'dt': 1550950864, 'sys': {'message': 0.0034, 'country': 'ZA', 'sunrise': 1550895928, 'sunset': 1550942795}, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# severobaykalsk
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=severobaykalsk
# {'coord': {'lon': 109.32, 'lat': 55.65}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 260.01, 'pressure': 1028.14, 'humidity': 78, 'temp_min': 260.01, 'temp_max': 260.01, 'sea_level': 1028.14, 'grnd_level': 897.78}, 'wind': {'speed': 1.16, 'deg': 222}, 'clouds': {'all': 68}, 'dt': 1550950865, 'sys': {'message': 0.0045, 'country': 'RU', 'sunrise': 1550879276, 'sunset': 1550916305}, 'id': 2016910, 'name': 'Severobaykalsk', 'cod': 200}
# papayal
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=papayal
# {'coord': {'lon': -79.18, 'lat': -2.43}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 293.15, 'pressure': 1025, 'humidity': 60, 'temp_min': 293.15, 'temp_max': 293.15}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 90}, 'clouds': {'all': 90}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 8519, 'message': 0.0029, 'country': 'EC', 'sunrise': 1550921098, 'sunset': 1550964893}, 'id': 3654853, 'name': 'Papayal', 'cod': 200}
# leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=leningradskiy
# {'coord': {'lon': 178.42, 'lat': 69.38}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 251.71, 'pressure': 1010.18, 'humidity': 88, 'temp_min': 251.71, 'temp_max': 251.71, 'sea_level': 1010.18, 'grnd_level': 1007.46}, 'wind': {'speed': 4.31, 'deg': 309}, 'clouds': {'all': 88}, 'dt': 1550950865, 'sys': {'message': 0.0034, 'country': 'RU', 'sunrise': 1550865482, 'sunset': 1550896973}, 'id': 2123814, 'name': 'Leningradskiy', 'cod': 200}
# dikson
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=dikson
# {'coord': {'lon': 80.55, 'lat': 73.51}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 257.66, 'pressure': 996.34, 'humidity': 87, 'temp_min': 257.66, 'temp_max': 257.66, 'sea_level': 996.34, 'grnd_level': 995.94}, 'wind': {'speed': 13.46, 'deg': 217}, 'clouds': {'all': 76}, 'dt': 1550950865, 'sys': {'message': 0.0042, 'country': 'RU', 'sunrise': 1550890646, 'sunset': 1550918802}, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# rocha
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=rocha
# {'coord': {'lon': -54.34, 'lat': -34.48}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 295.535, 'pressure': 1003.42, 'humidity': 95, 'temp_min': 295.535, 'temp_max': 295.535, 'sea_level': 1003.42, 'grnd_level': 986.98}, 'wind': {'speed': 3.41, 'deg': 280}, 'rain': {'3h': 1.775}, 'clouds': {'all': 48}, 'dt': 1550950866, 'sys': {'message': 0.0029, 'country': 'UY', 'sunrise': 1550913594, 'sunset': 1550960443}, 'id': 3440777, 'name': 'Rocha', 'cod': 200}
# sibu
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=sibu
# {'coord': {'lon': 111.83, 'lat': 2.29}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 298.15, 'pressure': 1009, 'humidity': 94, 'temp_min': 298.15, 'temp_max': 298.15}, 'visibility': 10000, 'wind': {'speed': 1}, 'clouds': {'all': 75}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 9369, 'message': 0.0036, 'country': 'MY', 'sunrise': 1550875453, 'sunset': 1550918867}, 'id': 1735902, 'name': 'Sibu', 'cod': 200}
# nantong
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=nantong
# {'coord': {'lon': 120.89, 'lat': 31.98}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 270.585, 'pressure': 1024.18, 'humidity': 100, 'temp_min': 270.585, 'temp_max': 270.585, 'sea_level': 1024.18, 'grnd_level': 1023.06}, 'wind': {'speed': 1.16, 'deg': 70.5003}, 'clouds': {'all': 0}, 'dt': 1550950866, 'sys': {'message': 0.0038, 'country': 'CN', 'sunrise': 1550874623, 'sunset': 1550915373}, 'id': 1799722, 'name': 'Nantong', 'cod': 200}
# lebu
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=lebu
# {'coord': {'lon': 38.73, 'lat': 8.96}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 284.96, 'pressure': 1011.34, 'humidity': 76, 'temp_min': 284.96, 'temp_max': 284.96, 'sea_level': 1011.34, 'grnd_level': 767.94}, 'wind': {'speed': 1.86, 'deg': 79.5003}, 'clouds': {'all': 20}, 'dt': 1550950867, 'sys': {'message': 0.0034, 'country': 'ET', 'sunrise': 1550893267, 'sunset': 1550936142}, 'id': 344979, 'name': 'Lebu', 'cod': 200}
# jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=jamestown
# {'coord': {'lon': 138.6, 'lat': -33.21}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 289.26, 'pressure': 1020.46, 'humidity': 64, 'temp_min': 289.26, 'temp_max': 289.26, 'sea_level': 1020.46, 'grnd_level': 962.98}, 'wind': {'speed': 3.46, 'deg': 70.0003}, 'clouds': {'all': 0}, 'dt': 1550950867, 'sys': {'message': 0.0034, 'country': 'AU', 'sunrise': 1550867340, 'sunset': 1550914097}, 'id': 2069194, 'name': 'Jamestown', 'cod': 200}
# bafoulabe
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=bafoulabe
# {'coord': {'lon': -10.83, 'lat': 13.81}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 295.835, 'pressure': 1012.46, 'humidity': 30, 'temp_min': 295.835, 'temp_max': 295.835, 'sea_level': 1012.46, 'grnd_level': 990.58}, 'wind': {'speed': 3.46, 'deg': 44.0003}, 'clouds': {'all': 0}, 'dt': 1550950867, 'sys': {'message': 0.0039, 'country': 'ML', 'sunrise': 1550905360, 'sunset': 1550947840}, 'id': 2460755, 'name': 'Bafoulabe', 'cod': 200}
# illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# Oops, City          illoqqortoormiut
# Temp                       NaN
# Humidity                   NaN
# Cloudiness                 NaN
# Wind Speed                 NaN
# lat                        NaN
# lon                        NaN
# Name: 98, dtype: object doesn't exist.
# bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=d5b774ebf0102f943e047d9ad75e3808&q=bredasdorp
# {'coord': {'lon': 20.04, 'lat': -34.53}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 294.15, 'pressure': 1014, 'humidity': 73, 'temp_min': 294.15, 'temp_max': 294.15}, 'wind': {'speed': 1.5, 'deg': 180}, 'clouds': {'all': 0}, 'dt': 1550948400, 'sys': {'type': 1, 'id': 1966, 'message': 0.0039, 'country': 'ZA', 'sunrise': 1550895728, 'sunset': 1550942610}, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}

# %%
df2
# Out:
#                City     Temp  Humidity  Cloudiness  Wind Speed    lat     lon
# 0      saint george  276.220      80.0        90.0        3.10  39.45   22.34
# 1            atuona  300.660     100.0         0.0        7.31  -9.80 -139.03
# 2            bethel  271.630      81.0         1.0        5.10  60.79 -161.76
# 3             kapaa  296.150      69.0         1.0        2.10  22.08 -159.32
# 4        chokurdakh  238.360       0.0        12.0        2.41  70.62  147.90
# 5           kahului  295.490      83.0        75.0        2.60  20.89 -156.47
# 6              sola  280.590      81.0        40.0        6.70  58.89    5.65
# 7          katsuura  276.150      69.0        40.0        3.60  33.93  134.50
# 8           rikitea  300.085      99.0        68.0        4.11 -23.12 -134.97
# 9        talcahuano  294.150      56.0         0.0        9.80 -36.72  -73.12
# 10         thompson  260.150      65.0        75.0        4.10  55.74  -97.86
# 11     punta arenas  282.150      49.0         0.0        9.80 -53.16  -70.91
# 12        rosenberg  295.230      37.0         1.0        5.10  29.56  -95.81
# 13         barcelos  287.150      67.0         0.0        1.50  41.53   -8.62
# 14          mataura  282.835      89.0        92.0        2.96 -46.19  168.86
# 15     longyearbyen  267.150      73.0        75.0        6.70  78.22   15.63
# 16        busselton  290.710     100.0         0.0        4.61 -33.64  115.35
# 17         bobonong      NaN       NaN         NaN         NaN    NaN     NaN
# 18        mahaicony      NaN       NaN         NaN         NaN    NaN     NaN
# 19   kulhudhuffushi  301.035      99.0         0.0        3.86   6.62   73.07
# 20           faanui  301.710      98.0         0.0        6.81 -16.48 -151.75
# 21      mys shmidta      NaN       NaN         NaN         NaN    NaN     NaN
# 22          ushuaia  280.150      56.0        75.0        7.70 -54.81  -68.31
# 23     fianarantsoa  291.135      95.0        56.0        1.06 -21.45   47.09
# 24     khorramshahr  289.710      82.0         0.0        1.00  30.43   48.18
# 25           karwar  295.960      50.0         0.0        0.06  14.80   74.13
# 26            airai  292.010      86.0         0.0        0.61  -8.93  125.41
# 27         klaksvik  280.150      81.0         0.0        9.80  62.23   -6.59
# 28            tiksi  244.885      27.0        32.0        4.06  71.64  128.87
# 29          angoche  300.585     100.0        76.0        4.11 -16.23   39.91
# ..              ...      ...       ...         ...         ...    ...     ...
# 585           rohru  270.335      57.0        56.0        0.71  31.20   77.75
# 586    isla mujeres  301.150      74.0        40.0        7.20  21.23  -86.73
# 587          usinsk  260.085      78.0        92.0        6.11  66.00   57.56
# 588          conner  285.760      90.0         0.0        0.76  17.80  121.32
# 589        balakhta  262.260      71.0        48.0        1.51  55.38   91.62
# 590            buin  302.650      32.0        20.0        2.60 -33.73  -70.74
# 591        bucerias  297.150      73.0        90.0        5.10  20.76 -105.33
# 592           jiazi  291.150      93.0        75.0        5.00  19.61  110.49
# 593         chotila  292.635      34.0         0.0        2.51  22.42   71.20
# 594            nome  296.430      49.0        90.0        5.70  30.04  -94.42
# 595       abbeville  281.630      76.0         0.0        2.10  50.11    1.83
# 596           gamba  250.910      43.0         0.0        2.51  28.28   88.52
# 597        bilibino  242.235      33.0        48.0        1.26  68.06  166.44
# 598          kuytun  265.385      77.0        88.0        1.71  54.34  101.51
# 599           ambon  284.090      81.0         0.0        2.10  47.55   -2.56
# 600        marsabit  296.535      71.0        36.0        2.66   2.34   37.99
# 601       loandjili  299.085      93.0        48.0        2.56  -4.77   11.87
# 602      porto novo  304.150      55.0        40.0        2.60 -23.68  -45.44
# 603    gloversville  274.230      58.0         1.0        3.60  43.05  -74.34
# 604        meulaboh  298.985     100.0        64.0        1.46   4.14   96.13
# 605         mashhad  279.150      60.0        40.0        1.06  36.30   59.61
# 606            nuuk  265.150      61.0        75.0        7.20  64.17  -51.74
# 607       rawannawi      NaN       NaN         NaN         NaN    NaN     NaN
# 608          ilorin  295.885      91.0        32.0        1.46   8.50    4.55
# 609      carutapera  299.460      89.0        64.0        3.11  -1.20  -46.02
# 610   lago da pedra      NaN       NaN         NaN         NaN    NaN     NaN
# 611           hobyo  298.710      85.0        92.0        6.61   5.35   48.53
# 612         mokrous  256.485      59.0         0.0        1.66  51.24   47.51
# 613     deputatskiy  228.710       0.0         0.0        1.21  69.30  139.90
# 614         leiyang  278.485      98.0        92.0        1.86  26.42  112.85
#
# [615 rows x 7 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
df2.columns
# Out:
# Index(['City', 'Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'lat', 'lon'], dtype='object')

# %%
plt.scatter(df2['Temp'], df2['lat'], df2['lon'], marker="o", facecolors="red", edgecolors="black")

# %%
plt.scatter(df2['Humidity'], df2['lat'], df2['lon'], marker="o", facecolors="red", edgecolors="black")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df2['Cloudiness'], df2['lat'], df2['lon'], marker="o", facecolors="red", edgecolors="black")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df2['Wind Speed'], df2['lat'], df2['lon'], marker="o", facecolors="red", edgecolors="black")
